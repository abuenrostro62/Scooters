# %%
import pandas as pd
import datetime as dt
import time

# %%
scooter = pd.read_json('short.json')

# %%
# # Replace column name spacing with _
scooter.columns = scooter.columns.str.replace(' ', '_')
scooter
# Out:
#                                 Trip_ID              Start_Time  Distance  \
# 0  f70d8d51-8353-5daf-a94b-05bf4eef0e64  07/04/2019 12:00:00 PM      2591
# 1  1219adef-c969-36f4-1219-adefc96936f4  08/16/2019 01:00:00 PM       772
# 2  12d4b35e-8c82-4a18-b77c-dd5061b17b56  07/22/2019 04:00:00 PM       817
# 3  123531ec-408f-7592-1235-31ec408f7592  09/06/2019 09:00:00 AM       386
# 4  15b69e57-8a22-40b1-a682-42d52fbeddcb  07/14/2019 07:00:00 PM      6538
# 5  11fca7b6-346a-8436-11fc-a7b6346a8436  07/25/2019 12:00:00 PM       370
# 6  37d991bd-1b00-46f3-b66e-aa33c88456cc  09/20/2019 05:00:00 PM      1048
# 7  38bf3c5e-b783-54ce-8f9c-efe18b6c912d  06/19/2019 01:00:00 PM       627
# 8  3467e6cc-1660-5a84-b2bc-c752f8ccc1aa  07/31/2019 06:00:00 PM      1174
# 9  179972bc-9418-5fca-9182-34324d9aebfb  07/07/2019 03:00:00 PM        48
#
#    Duration  Start_Tract    End_Tract  Start_Community_#  End_Community_#  \
# 0       772  17031240500  17031221300                 24               22
# ...

# %%
scooter.dtypes
# Out:
# Trip_ID                  object
# Start_Time               object
# Distance                  int64
# Duration                  int64
# Start_Tract               int64
# End_Tract                 int64
# Start_Community_#         int64
# End_Community_#           int64
# Start_Community_Name     object
# End_Community_Name       object
# Start_Lat               float64
# Start_Long              float64
# End_Lat                 float64
# End_Long                float64
# dtype: object

# %%
scooter['Start_Time']=pd.to_datetime(scooter.Start_Time)
scooter
# Out:
#                                 Trip_ID          Start_Time  Distance  \
# 0  f70d8d51-8353-5daf-a94b-05bf4eef0e64 2019-07-04 12:00:00      2591
# 1  1219adef-c969-36f4-1219-adefc96936f4 2019-08-16 13:00:00       772
# 2  12d4b35e-8c82-4a18-b77c-dd5061b17b56 2019-07-22 16:00:00       817
# 3  123531ec-408f-7592-1235-31ec408f7592 2019-09-06 09:00:00       386
# 4  15b69e57-8a22-40b1-a682-42d52fbeddcb 2019-07-14 19:00:00      6538
# 5  11fca7b6-346a-8436-11fc-a7b6346a8436 2019-07-25 12:00:00       370
# 6  37d991bd-1b00-46f3-b66e-aa33c88456cc 2019-09-20 17:00:00      1048
# 7  38bf3c5e-b783-54ce-8f9c-efe18b6c912d 2019-06-19 13:00:00       627
# 8  3467e6cc-1660-5a84-b2bc-c752f8ccc1aa 2019-07-31 18:00:00      1174
# 9  179972bc-9418-5fca-9182-34324d9aebfb 2019-07-07 15:00:00        48
#
#    Duration  Start_Tract    End_Tract  Start_Community_#  End_Community_#  \
# 0       772  17031240500  17031221300                 24               22
# ...

# %%
# # Identify Weekday Name and add column
scooter['Weekday']=scooter.Start_Time.dt.weekday_name
scooter
# Out:
#                                 Trip_ID          Start_Time  Distance  \
# 0  f70d8d51-8353-5daf-a94b-05bf4eef0e64 2019-07-04 12:00:00      2591
# 1  1219adef-c969-36f4-1219-adefc96936f4 2019-08-16 13:00:00       772
# 2  12d4b35e-8c82-4a18-b77c-dd5061b17b56 2019-07-22 16:00:00       817
# 3  123531ec-408f-7592-1235-31ec408f7592 2019-09-06 09:00:00       386
# 4  15b69e57-8a22-40b1-a682-42d52fbeddcb 2019-07-14 19:00:00      6538
# 5  11fca7b6-346a-8436-11fc-a7b6346a8436 2019-07-25 12:00:00       370
# 6  37d991bd-1b00-46f3-b66e-aa33c88456cc 2019-09-20 17:00:00      1048
# 7  38bf3c5e-b783-54ce-8f9c-efe18b6c912d 2019-06-19 13:00:00       627
# 8  3467e6cc-1660-5a84-b2bc-c752f8ccc1aa 2019-07-31 18:00:00      1174
# 9  179972bc-9418-5fca-9182-34324d9aebfb 2019-07-07 15:00:00        48
#
#    Duration  Start_Tract    End_Tract  Start_Community_#  End_Community_#  \
# 0       772  17031240500  17031221300                 24               22
# ...

# %%
# Identify start time & convert to 12hr format
scooter['Start'] =scooter.Start_Time.dt.date
scooter

#  convert time to 12hr
# Out:
#                                 Trip_ID          Start_Time  Distance  \
# 0  f70d8d51-8353-5daf-a94b-05bf4eef0e64 2019-07-04 12:00:00      2591
# 1  1219adef-c969-36f4-1219-adefc96936f4 2019-08-16 13:00:00       772
# 2  12d4b35e-8c82-4a18-b77c-dd5061b17b56 2019-07-22 16:00:00       817
# 3  123531ec-408f-7592-1235-31ec408f7592 2019-09-06 09:00:00       386
# 4  15b69e57-8a22-40b1-a682-42d52fbeddcb 2019-07-14 19:00:00      6538
# 5  11fca7b6-346a-8436-11fc-a7b6346a8436 2019-07-25 12:00:00       370
# 6  37d991bd-1b00-46f3-b66e-aa33c88456cc 2019-09-20 17:00:00      1048
# 7  38bf3c5e-b783-54ce-8f9c-efe18b6c912d 2019-06-19 13:00:00       627
# 8  3467e6cc-1660-5a84-b2bc-c752f8ccc1aa 2019-07-31 18:00:00      1174
# 9  179972bc-9418-5fca-9182-34324d9aebfb 2019-07-07 15:00:00        48
#
#    Duration  Start_Tract    End_Tract  Start_Community_#  End_Community_#  \
# 0       772  17031240500  17031221300                 24               22
# ...

# %%
# Calculate Distance by miles and add a new column
scooter['Miles']= (scooter.Distance/1609).round(decimals=2)
scooter
# Out:
#                                 Trip_ID          Start_Time  Distance  \
# 0  f70d8d51-8353-5daf-a94b-05bf4eef0e64 2019-07-04 12:00:00      2591
# 1  1219adef-c969-36f4-1219-adefc96936f4 2019-08-16 13:00:00       772
# 2  12d4b35e-8c82-4a18-b77c-dd5061b17b56 2019-07-22 16:00:00       817
# 3  123531ec-408f-7592-1235-31ec408f7592 2019-09-06 09:00:00       386
# 4  15b69e57-8a22-40b1-a682-42d52fbeddcb 2019-07-14 19:00:00      6538
# 5  11fca7b6-346a-8436-11fc-a7b6346a8436 2019-07-25 12:00:00       370
# 6  37d991bd-1b00-46f3-b66e-aa33c88456cc 2019-09-20 17:00:00      1048
# 7  38bf3c5e-b783-54ce-8f9c-efe18b6c912d 2019-06-19 13:00:00       627
# 8  3467e6cc-1660-5a84-b2bc-c752f8ccc1aa 2019-07-31 18:00:00      1174
# 9  179972bc-9418-5fca-9182-34324d9aebfb 2019-07-07 15:00:00        48
#
#    Duration  Start_Tract    End_Tract  Start_Community_#  End_Community_#  \
# 0       772  17031240500  17031221300                 24               22
# ...

# %%
# Convert seconds to hh:mm

# %%
# Convert and save dataframe as json file
# scooter.to_json(r'Path to store the exported JSON file\scooter.json')

# %%
convert dataframe to json
scooter.to_json(orient='index')
# Out:
# '{"0":{"Trip_ID":"f70d8d51-8353-5daf-a94b-05bf4eef0e64","Start_Time":1562241600000,"Distance":2591,"Duration":772,"Start_Tract":17031240500,"End_Tract":17031221300,"Start_Community_#":24,"End_Community_#":22,"Start_Community_Name":"WEST TOWN","End_Community_Name":"LOGAN SQUARE","Start_Lat":41.9119700419,"Start_Long":-87.683636525,"End_Lat":41.9211256768,"End_Long":-87.6997540616},"1":{"Trip_ID":"1219adef-c969-36f4-1219-adefc96936f4","Start_Time":1565960400000,"Distance":772,"Duration":794,"Start_Tract":17031833000,"End_Tract":17031281900,"Start_Community_#":28,"End_Community_#":28,"Start_Community_Name":"NEAR WEST SIDE","End_Community_Name":"NEAR WEST SIDE","Start_Lat":41.8852882458,"Start_Long":-87.6572424682,"End_Lat":41.8792479502,"End_Long":-87.6426236342},"2":{"Trip_ID":"12d4b35e-8c82-4a18-b77c-dd5061b17b56","Start_Time":1563811200000,"Distance":817,"Duration":234,"Start_Tract":17031833100,"End_Tract":17031833100,"Start_Community_#":28,"End_Community_#":28,"Start_Community_Name"
# ...
